# %%
import pandas as pd
import numpy as np
import seaborn as sns 

import missingno as msno

import matplotlib.pyplot as plt
import matplotlib

from sklearn.tree import export_graphviz
import graphviz

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor as GBR

import warnings
warnings.filterwarnings(action='ignore')

matplotlib.rc('font',family='Gothic')
plt.rc('font',family = 'Gothic')

# %%
df = pd.read_csv('final_df_all_ver0.4.csv')
df
# Out:
#      chaju_id credit_class  score_risk gender  age agegroup       job  \
# 0      C-1001          C05         478     남성   30      30대    기능/노무직
# 1      C-1002          C05         484     여성   66      60대      전업주부
# 2      C-1003          C05         478     남성   43      40대   판매/서비스직
# 3      C-1004          C05         445     남성   28      20대     무직/기타
# 4      C-1005          C05         421     남성   52      50대  행정관리/전문직
# ...       ...          ...         ...    ...  ...      ...       ...
# 1424   C-2993          C04         398     여성   35      30대       사무직
# 1425   C-2994          C05         468     남성   42      40대    기능/노무직
# 1426   C-2995          C06         528     여성   39      30대      전업주부
# 1427   C-2996          C05         448     남성   41      40대       사무직
# 1428   C-3000          C06         571     여성   59      50대      전업주부
#
#           edu dwell_type house_type  ... loan_period Pcard_loan_amt  \
# ...

# %%
msno.matrix(df=df.iloc[:, :], figsize=(8, 8), color=(0.8, 0.4, 0.4))
# Out:
# <AxesSubplot:>
# findfont: Font family ['Gothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Gothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Gothic'] not found. Falling back to DejaVu Sans.

# %%
df = df.replace([np.inf, -np.inf], 100)

# %%
df.columns
# Out:
# Index(['chaju_id', 'credit_class', 'score_risk', 'gender', 'age', 'agegroup',
#        'job', 'edu', 'dwell_type', 'house_type', 'marriage', 'income_home_grp',
#        'expenditure_grp', 'child_cd', 'no_child', 'flag_priv_biz_cd',
#        'card_count', 'card_period', 'loan_period', 'Pcard_loan_amt',
#        'over_period', 'Pcard_over_amt', 'over_amt', 'loan_amt_final2',
#        'del_rate', 'loan_count', 'overdue_count', 'income_ind_grp'],
#       dtype='object')

# %%
df = df.drop(['chaju_id', 'credit_class', 'score_risk', 'over_amt', 'loan_amt_final2','loan_count'],axis=1)

# %%
df.describe()
# Out:
#                age     no_child   card_count  card_period  loan_period  \
# count  1429.000000  1429.000000  1429.000000  1429.000000  1429.000000
# mean     48.215535     1.392582     2.600420    53.965710    41.130161
# std      13.785665     0.905462     1.975841    41.175355    36.797175
# min      21.000000     0.000000     0.000000     0.000000     0.000000
# 25%      38.000000     1.000000     1.000000    25.000000    15.000000
# 50%      48.000000     2.000000     2.000000    50.000000    28.000000
# 75%      58.000000     2.000000     4.000000    83.000000    59.000000
# max      85.000000     3.000000    10.000000   176.000000   193.000000
#
#        Pcard_loan_amt  over_period  Pcard_over_amt     del_rate  overdue_count
# count    1.429000e+03  1429.000000    1.429000e+03  1429.000000    1429.000000
# mean     2.080896e+05     7.546536    1.478376e+05    17.215474       0.618614
# std      1.569941e+06    18.144305    3.862480e+06    33.514757       1.384474
# ...

# %% [markdown]
# # GradientBoostingRegressor

# %%
df_raw_dummy=pd.get_dummies(df)
df_raw_x = df_raw_dummy.drop("del_rate",axis = 1, inplace = False)
df_raw_y = df_raw_dummy["del_rate"]

# %%
df_train_x, df_test_x, df_train_y, df_test_y = train_test_split(df_raw_x, df_raw_y, test_size = 0.3)
print('train data x size:{}'.format(df_train_x.shape))
print('train data y size:{}'.format(df_train_y.shape))
print('test data x size:{}'.format(df_test_x.shape))
print('test data y size:{}'.format(df_test_y.shape))
# Out:
# train data x size:(1000, 80)
# train data y size:(1000,)
# test data x size:(429, 80)
# test data y size:(429,)

# %%
gb_uncustomized = GBR()
gb_uncustomized.fit(df_train_x, df_train_y)
#train data 설명력
print('Score on training set:{:.3f}'.format(gb_uncustomized.score(df_train_x, df_train_y)))
#test data 설명력
print('Score on test set:{:.3f}'.format(gb_uncustomized.score(df_test_x, df_test_y)))
# Out:
# Score on training set:0.917
# Score on test set:0.854

# %%
gb_final = GBR(n_estimators=100,
               min_samples_leaf = 20, 
               min_samples_split =30,
               max_depth = 5, 
               learning_rate = 0.1,
               random_state= 1234)
gb_final.fit(df_train_x, df_train_y)
y_pred = gb_final.predict(df_test_x)
print('Score on training set:{:.3f}'.format(gb_final.score(df_train_x, df_train_y)))
print('Score on test set:{:.3f}'.format(gb_final.score(df_test_x,df_test_y)))
# Out:
# Score on training set:0.933
# Score on test set:0.851

# %%
y_pred = gb_final.predict(df_test_x)
print(y_pred)
len(y_pred)
# Out:
# [ 3.60306132e-01 -1.41550189e+00  4.43393115e+01 -1.36210867e+00
#  -1.54999906e-01  2.96919435e-01  9.51866504e-01 -1.96598828e+00
#  -2.52787887e+00  5.27741665e+01  9.99794431e+01  6.77589168e+01
#  -1.70030099e-01 -2.27535111e+00  8.26310851e-01  4.13873312e+01
#   4.81903947e-02 -6.19916928e-01  5.73783212e+01 -7.77913555e-01
#  -9.52825574e-01 -1.36138422e-01  2.76022001e-01  8.24091461e-01
#  -2.84059384e-01  6.11827277e-01 -1.78026181e-01  3.04851562e+01
#   9.60361739e+01 -1.40817229e-02 -1.01238929e+00  6.81399347e-01
#   5.85123493e-01 -6.80290358e-01  1.87103616e-01  2.18536669e-01
#   3.47219708e+00 -5.28485453e-02  3.30337650e-01 -3.09873767e+00
#   1.59276508e-01 -3.07859565e-02  9.63742770e+01  6.13037457e+01
#   9.76022536e-01 -7.56659275e-01  1.04877222e+00  7.09841529e+01
#  -9.13649070e-02 -2.70509517e+00 -1.89011754e+00  7.74391175e+01
#   5.59683580e+01  1.76174043e+01 -4.45422200e-02  1.58684010e-01
# ...

# %%
v_feature_name = df_train_x.columns

df_importance= pd.DataFrame()
df_importance['Feature'] = v_feature_name
df_importance['Importance'] = gb_final.feature_importances_

df_importance.sort_values('Importance',ascending=False, inplace = True)
df_importance.round(3)
# Out:
#                       Feature  Importance
# 6                 over_period       0.481
# 8               overdue_count       0.311
# 4                 loan_period       0.152
# 0                         age       0.016
# 2                  card_count       0.008
# ..                        ...         ...
# 38              dwell_type_자가       0.000
# 36            dwell_type_영구임대       0.000
# 35           dwell_type_사택/기타       0.000
# 34                edu_초등학교 졸업       0.000
# 56  income_home_grp_700-799만원      -0.000
#
# [80 rows x 2 columns]

# %%
plt.figure(figsize=(8,20))
df_importance.sort_values('Importance',ascending=True, inplace =True)
coordinates=range(len(df_importance))
plt.barh(y=coordinates, width = df_importance['Importance'])
plt.yticks(coordinates, df_importance['Feature'])
plt.xlabel('feature importance')
plt.ylabel('feature')
# Out:
# Text(0, 0.5, 'feature')
# findfont: Font family ['Gothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # XGBOOST

# %%
from xgboost import XGBRegressor
from xgboost import plot_importance

# %%
xgb= XGBRegressor(max_depth = 3, 
                          n_estimators = 200,
                          learning_rate= .12)
xgb.fit(df_train_x,df_train_y)
print("Score on training set:{:.3f}".format(xgb.score(df_train_x,df_train_y)))
print("Score on test set:{:.3f}".format(xgb.score(df_test_x,df_test_y)))
# Out:
# Score on training set:0.946
# Score on test set:0.845

# %%
v_feature_name = df_train_x.columns

df_importance= pd.DataFrame()
df_importance['Feature'] = v_feature_name
df_importance['Importance'] = xgb.feature_importances_

df_importance.sort_values('Importance',ascending=False, inplace = True)
df_importance.round(3)
# Out:
#                    Feature  Importance
# 6              over_period       0.336
# 4              loan_period       0.101
# 8            overdue_count       0.038
# 46   marriage_기타(이혼/별거/사별)       0.033
# 24            job_행정관리/전문직       0.027
# ..                     ...         ...
# 17          agegroup_80대이상       0.000
# 16            agegroup_70대       0.000
# 11            agegroup_20대       0.000
# 10               gender_여성       0.000
# 79  income_ind_grp_99만원 이하       0.000
#
# [80 rows x 2 columns]

# %%
plt.figure(figsize=(8,20))
df_importance.sort_values('Importance',ascending=True, inplace =True)
coordinates=range(len(df_importance))
plt.barh(y=coordinates, width = df_importance['Importance'])
plt.yticks(coordinates, df_importance['Feature'])
plt.xlabel('feature importance')
plt.ylabel('feature')
# Out:
# Text(0, 0.5, 'feature')

# %%
y_pred = xgb.predict(df_raw_x)

# %%
df_pred = pd.DataFrame(y_pred)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(df_pred)
np_pred = scaler.transform(df_pred)
float(np_pred[0])*100
# Out:
# 26.18415355682373

# %%
for i in range(len(df_pred)):
    df_pred.iloc[i,0] = int(float(np_pred[i]) * 1000)

# %%
df2 = pd.read_csv('final_df_all_ver0.4.csv')

# %%
df_id = df2.chaju_id
df_id
# Out:
# 0       C-1001
# 1       C-1002
# 2       C-1003
# 3       C-1004
# 4       C-1005
#          ...
# 1424    C-2993
# 1425    C-2994
# 1426    C-2995
# 1427    C-2996
# 1428    C-3000
# Name: chaju_id, Length: 1429, dtype: object

# %%
df_pred = pd.concat([df_id,df_pred],axis=1)
df_pred
# Out:
#      chaju_id      0
# 0      C-1001  261.0
# 1      C-1002  152.0
# 2      C-1003  151.0
# 3      C-1004  161.0
# 4      C-1005  157.0
# ...       ...    ...
# 1424   C-2993  180.0
# 1425   C-2994  546.0
# 1426   C-2995  164.0
# 1427   C-2996  164.0
# 1428   C-3000  161.0
#
# [1429 rows x 2 columns]

# %%
df_pred.rename(columns={0:'predict'},inplace=True)
df_pred
# Out:
#      chaju_id  predict
# 0      C-1001    261.0
# 1      C-1002    152.0
# 2      C-1003    151.0
# 3      C-1004    161.0
# 4      C-1005    157.0
# ...       ...      ...
# 1424   C-2993    180.0
# 1425   C-2994    546.0
# 1426   C-2995    164.0
# 1427   C-2996    164.0
# 1428   C-3000    161.0
#
# [1429 rows x 2 columns]

# %%
df_pred.to_csv('df_pred_xgb.csv')
