# %%
import pandas as pd
import numpy as np 

import matplotlib.pyplot as plt
import seaborn as sns

import missingno as msno
import warnings

warnings.filterwarnings(action='ignore')
plt.rc('font', family='Noto Sans CJK JP')

# %%
df_all = pd.read_csv('ALL_info.csv', engine= 'python', encoding='cp949')
df_all
# Out:
#       Unnamed: 0 chaju_id credit_class  score_risk gender  age agegroup  \
# 0              0   C-1001          C05         478     남성   30      30대
# 1              1   C-1002          C05         484     여성   66      60대
# 2              2   C-1003          C05         478     남성   43      40대
# 3              3   C-1004          C05         445     남성   28      20대
# 4              4   C-1005          C05         421     남성   52      50대
# ...          ...      ...          ...         ...    ...  ...      ...
# 1979        1979   C-2996          C05         448     남성   41      40대
# 1980        1980   C-2997          C04         308     남성   37      30대
# 1981        1981   C-2998          C04         371     여성   50      50대
# 1982        1982   C-2999          C04         398     남성   42      40대
# 1983        1983   C-3000          C06         571     여성   59      50대
#
#            job      edu dwell_type  ... Pcard_over_amt   over_amt  \
# ...

# %%
#결측치 확인 
msno.matrix(df=df_all.iloc[:, :], figsize=(20, 20), color=(0.8, 0.4, 0.4))
# Out:
# <AxesSubplot:>

# %%
df_all[['card_count']]
# Out:
#       card_count
# 0            4.0
# 1            6.0
# 2            2.0
# 3            1.0
# 4            3.0
# ...          ...
# 1973         4.0
# 1974         4.0
# 1978         5.0
# 1979         1.0
# 1983         4.0
#
# [1145 rows x 1 columns]

# %%
df_all = df_all.dropna(axis=0)
df_all
# Out:
#       Unnamed: 0 chaju_id credit_class  score_risk gender  age agegroup  \
# 0              0   C-1001          C05         478     남성   30      30대
# 1              1   C-1002          C05         484     여성   66      60대
# 2              2   C-1003          C05         478     남성   43      40대
# 3              3   C-1004          C05         445     남성   28      20대
# 4              4   C-1005          C05         421     남성   52      50대
# ...          ...      ...          ...         ...    ...  ...      ...
# 1973        1973   C-2990          C06         574     남성   64      60대
# 1974        1974   C-2991          C06         528     여성   39      30대
# 1978        1978   C-2995          C06         528     여성   39      30대
# 1979        1979   C-2996          C05         448     남성   41      40대
# 1983        1983   C-3000          C06         571     여성   59      50대
#
#            job      edu dwell_type  ... Pcard_over_amt   over_amt  \
# ...

# %%
idx = df_all[df_all['연체율S98반영'].isnull() == True].index
df_all = df_all.drop(idx)
df_all
# Out:
#       Unnamed: 0 chaju_id credit_class  score_risk gender  age agegroup  \
# 0              0   C-1001          C05         478     남성   30      30대
# 1              1   C-1002          C05         484     여성   66      60대
# 2              2   C-1003          C05         478     남성   43      40대
# 3              3   C-1004          C05         445     남성   28      20대
# 4              4   C-1005          C05         421     남성   52      50대
# ...          ...      ...          ...         ...    ...  ...      ...
# 1973        1973   C-2990          C06         574     남성   64      60대
# 1974        1974   C-2991          C06         528     여성   39      30대
# 1978        1978   C-2995          C06         528     여성   39      30대
# 1979        1979   C-2996          C05         448     남성   41      40대
# 1983        1983   C-3000          C06         571     여성   59      50대
#
#            job      edu dwell_type  ... Pcard_over_amt   over_amt  \
# ...

# %%
#결측치 확인 
msno.matrix(df=df_all.iloc[:, :], figsize=(20, 20), color=(0.8, 0.4, 0.4))
# Out:
# <AxesSubplot:>

# %%
df_all.describe()
# Out:
#         Unnamed: 0   score_risk          age     no_child   card_count  \
# count  1166.000000  1166.000000  1166.000000  1166.000000  1166.000000
# mean    978.897084   468.024014    48.126930     1.420240     3.186964
# std     574.072503    93.983887    12.886071     0.878001     1.707153
# min       0.000000   227.000000    21.000000     0.000000     1.000000
# 25%     476.250000   408.000000    38.000000     1.000000     2.000000
# 50%     966.500000   468.000000    48.000000     2.000000     3.000000
# 75%    1468.750000   521.000000    57.000000     2.000000     4.000000
# max    1983.000000   824.000000    85.000000     3.000000    10.000000
#
#        card_period  loan_period  Pcard_loan_amt      loan_amt  over_period  \
# count  1166.000000  1166.000000    1.166000e+03  1.166000e+03  1166.000000
# mean     66.138079    45.770154    2.550257e+05  1.017166e+08     6.614065
# std      35.670750    37.793457    1.734690e+06  1.542414e+08    18.345289
# ...

# %%
df_all = df_all.replace([np.inf, -np.inf], np.nan)

# %%
df_all.describe()
# Out:
#         Unnamed: 0   score_risk          age     no_child   card_count  \
# count  1166.000000  1166.000000  1166.000000  1166.000000  1166.000000
# mean    978.897084   468.024014    48.126930     1.420240     3.186964
# std     574.072503    93.983887    12.886071     0.878001     1.707153
# min       0.000000   227.000000    21.000000     0.000000     1.000000
# 25%     476.250000   408.000000    38.000000     1.000000     2.000000
# 50%     966.500000   468.000000    48.000000     2.000000     3.000000
# 75%    1468.750000   521.000000    57.000000     2.000000     4.000000
# max    1983.000000   824.000000    85.000000     3.000000    10.000000
#
#        card_period  loan_period  Pcard_loan_amt      loan_amt  over_period  \
# count  1166.000000  1166.000000    1.166000e+03  1.166000e+03  1166.000000
# mean     66.138079    45.770154    2.550257e+05  1.017166e+08     6.614065
# std      35.670750    37.793457    1.734690e+06  1.542414e+08    18.345289
# ...

# %%
df_all[df_all['연체율S98반영']== 10600]
# Out:
#       Unnamed: 0 chaju_id credit_class  score_risk gender  age agegroup  \
# 1666        1666   C-2679          C05         428     남성   47      40대
#
#          job      edu dwell_type  ... Pcard_over_amt    over_amt  \
# 1666  기능/노무직  고등학교 졸업         자가  ...            0.0  53000000.0
#
#      over_normal_amt over_special_amt over_s98case_amt      연체율  \
# 1666      53000000.0              0.0              0.0  10600.0
#
#       loan_amt_final  연체율특채반영  loan_amt_final2  연체율S98반영
# 1666        500000.0  10600.0         500000.0   10600.0
#
# [1 rows x 34 columns]

# %%
df_all = df_all.drop(index=1666)

# %%
idx2 = df_all[df_all['연체율S98반영'] > 100].index

# %%
df_all = df_all.drop(idx2)

# %%
df_all
# Out:
#       Unnamed: 0 chaju_id credit_class  score_risk gender  age agegroup  \
# 0              0   C-1001          C05         478     남성   30      30대
# 1              1   C-1002          C05         484     여성   66      60대
# 2              2   C-1003          C05         478     남성   43      40대
# 3              3   C-1004          C05         445     남성   28      20대
# 4              4   C-1005          C05         421     남성   52      50대
# ...          ...      ...          ...         ...    ...  ...      ...
# 1973        1973   C-2990          C06         574     남성   64      60대
# 1974        1974   C-2991          C06         528     여성   39      30대
# 1978        1978   C-2995          C06         528     여성   39      30대
# 1979        1979   C-2996          C05         448     남성   41      40대
# 1983        1983   C-3000          C06         571     여성   59      50대
#
#            job      edu dwell_type  ... Pcard_over_amt   over_amt  \
# ...

# %%
sns.boxplot(x = df_all['gender'], y=df_all['연체율S98반영'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='연체율S98반영'>

# %%
sns.barplot(x = df_all['gender'], y = df_all['연체율S98반영'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='연체율S98반영'>

# %%
sns.displot(x=df_all['age'], y=df_all['연체율S98반영'], kind='hist')

# %%
sns.violinplot(x=df_all['gender'], y=df_all['연체율S98반영'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='연체율S98반영'>

# %%
sns.set(rc = {'figure.figsize':(20,20)})
sns.heatmap(df_all.corr(), annot = True, cmap = 'viridis' )
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x=df_all['age'], y=df_all['연체율S98반영'], kind = 'hex')
